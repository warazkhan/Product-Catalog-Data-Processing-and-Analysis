# %%
import pandas as pd
from pandasql import PandaSQL
import warnings #handling warnings.
pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore')

# %%
productCatalogDf = pd.read_csv('../data/product_catalog_cleaned.csv')

# %%
productCatalogDf.head(2)
# Out:
#   Manufacturernumber Articlenumber  EAN  \
# 0      0 601 6B4 000    06016B4000  NaN
# 1      0 601 6B4 000    06016B4000  NaN
#
#                                    Technical details  \
# 0  §Titel§Akku-Tauchsäge BITURBO GKT 18V-52 GC Pr...
# 1  §Titel§Akku-Tauchsäge BITURBO GKT 18V-52 GC Pr...
#
#                               Picture normal reduced  Depth m  Width m  \
# 0  'https://www.nexmart.com/media/catalog/ampshar...    0.254     0.36
# 1  'https://www.nexmart.com/media/catalog/ampshar...    0.254     0.36
#
#    Length m  Weight kg  Delivery time days  ... Language  Manufacturername  \
# 0     0.444      4.032                 NaN  ...       de             BOSCH
# 1     0.444      4.032                 NaN  ...       en             BOSCH
#
#   Short_description_quality Short_description_2_quality  \
# 0                      good                        good
# 1                      good                         bad
#
#   Manufacturer_product_count Product_length_category Has_image Volume_m3  \
# 0                        140                  Medium         1  0.040599
# 1                        140                  Medium         1  0.040599
#
#   Has_long_description Description_length
# 0                    1               1640
# 1                    0                  0
#
# [2 rows x 27 columns]

# %%
productCatalogDf.tail(2)
# Out:
#     Manufacturernumber Articlenumber           EAN  \
# 306            RALB2EU       RALB2EU  4.012079e+12
# 307            RALB2US       RALB2US  4.012079e+12
#
#                                      Technical details  \
# 306  §Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung...
# 307  §Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung...
#
#                                 Picture normal reduced  Depth m  Width m  \
# 306  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
# 307  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
#
#      Length m  Weight kg  Delivery time days  ... Language  Manufacturername  \
# 306       NaN       0.64                 NaN  ...       de             BOSCH
# 307       NaN       0.64                 NaN  ...       de             BOSCH
#
#     Short_description_quality Short_description_2_quality  \
# 306                      good                         bad
# 307                      good                         bad
#
#     Manufacturer_product_count Product_length_category Has_image Volume_m3  \
# 306                        140                     NaN         1       1.0
# 307                        140                     NaN         1       1.0
#
#     Has_long_description Description_length
# 306                    1                110
# 307                    1                 40
#
# [2 rows x 27 columns]

# %% [markdown]
# Which manufacturers have the biggest improvement potential in their data quality in absolute and relative numbers?

# %%
query = """
SELECT Manufacturername,
       COUNT(*) AS Total_Products,
       SUM(CASE WHEN Short_description_quality = 'bad' THEN 1 ELSE 0 END) + 
       SUM(CASE WHEN Short_description_2_quality = 'bad' THEN 1 ELSE 0 END) AS Total_Bad_Short_Descriptions
FROM productCatalogDf
GROUP BY Manufacturername
ORDER BY Total_Bad_Short_Descriptions DESC
"""
pandasql_instance = PandaSQL()
result = pandasql_instance(query, locals())
result
# Out:
#      Manufacturername  Total_Products  Total_Bad_Short_Descriptions
# 0                FEIN             100                           100
# 1  GUSTAV KLAUKE GMBH              40                            40
# 2        ROTHENBERGER              23                            23
# 3               BOSCH             140                            12
# 4             FISCHER               5                             0

# %% [markdown]
# What product variable/column (description or property) usually contains data of good quality per manufacturer? And what is the % of good quality records per variable/column and manufacturer?

# %%
query_rel = """
SELECT Manufacturername,
       ((ROUND(100.0 * SUM(CASE WHEN Short_description_quality = 'good' THEN 1 ELSE 0 END) / COUNT(*), 2))+
       (ROUND(100.0 * SUM(CASE WHEN Short_description_2_quality = 'good' THEN 1 ELSE 0 END) / COUNT(*), 2)))/2 as Good_Quality_Product_Percentage
FROM productCatalogDf
GROUP BY Manufacturername
ORDER BY Good_Quality_Product_Percentage DESC;
"""

pandasql_instance = PandaSQL()
result_rel = pandasql_instance(query_rel, locals())
result_rel
# Out:
#      Manufacturername  Good_Quality_Product_Percentage
# 0             FISCHER                          100.000
# 1               BOSCH                           95.715
# 2        ROTHENBERGER                           50.000
# 3  GUSTAV KLAUKE GMBH                           50.000
# 4                FEIN                           50.000
