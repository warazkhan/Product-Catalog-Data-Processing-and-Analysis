# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib.pyplot as plt
import warnings #handling warnings.
pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore')

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <ul style="list-style-type:none;">
#     <br>
#   <center><li style="font-weight: bold;font-family:Trebuchet MS;font-size:20px;font-style: italic;color:  black">DATASET 1</li></center>
#   <center><li style="font-weight: bold;font-family:Trebuchet MS;font-size:30px;font-style: italic;color:  darkble">MANUFACTURERS DATASET</li></center>
# </ul>
#     <br>
# </div>

# %%
manufacturersDf= pd.read_csv(r'../data/manufacturers.csv', sep=';')
manufacturersDf.head(4)
# Out:
#   Manufacturernumber Manufacturername
# 0      0 601 9K8 000            BOSCH
# 1        71222062000             FEIN
# 2      0 601 6B9 000            BOSCH
# 3      0 601 9K6 100            BOSCH

# %%
print('The Dataset contains {} rows & {} columns'.format(manufacturersDf.shape[0], manufacturersDf.shape[1]))
# Out:
# The Dataset contains 309 rows & 2 columns

# %%
manufacturersDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Manufacturernumber  285 non-null    object
#  1   Manufacturername    309 non-null    object
# dtypes: object(2)
# memory usage: 5.0+ KB

# %%
cleanManufacturersDf = manufacturersDf.copy()

# %%
def cleanBadValues(df, badValues, columns=None):
    if columns is None:
        columns = df.select_dtypes(include='object').columns
        
    foundBad = False
    for col in columns:
        df[col] = df[col].str.strip()
        if df[col].isin(badValues).any():
            foundBad = True
            df[col] = df[col].replace(badValues, np.nan)
    if foundBad:
        print("Bad values detected and replaced!")
    else:
        print("No Bad values found!")
    return df

badValues = ["None", "none", "null", "Null", "n/a", "N/A", "NA", "", " ", "-", "--", "'", "undefined", "missing", "<blank>", "???", "\n", "\t"]

# %%
cleanManufacturersDf = cleanBadValues(cleanManufacturersDf, badValues)
# Out:
# No Bad values found!

# %%
cleanManufacturersDf.isnull().sum()
# Out:
# Manufacturernumber    24
# Manufacturername       0
# dtype: int64

# %%
cleanManufacturersDf.dropna(subset=['Manufacturernumber'], inplace=True)

# %%
cleanManufacturersDf.describe()
# Out:
#        Manufacturernumber Manufacturername
# count                 285              285
# unique                285                5
# top         0 601 9K8 000            BOSCH
# freq                    1              117

# %%
cleanManufacturersDf['Manufacturernumber'].duplicated().sum()
# Out:
# 0

# %%
cleanManufacturersDf
# Out:
#     Manufacturernumber    Manufacturername
# 0        0 601 9K8 000               BOSCH
# 1          71222062000                FEIN
# 2        0 601 6B9 000               BOSCH
# 3        0 601 9K6 100               BOSCH
# 4        0 601 482 400               BOSCH
# ..                 ...                 ...
# 280            ES32CFB  GUSTAV KLAUKE GMBH
# 281      0 601 9J5 001               BOSCH
# 282        71221662000                FEIN
# 283        71700463000                FEIN
# 284      0 601 9J8 300               BOSCH
#
# [285 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <ul style="list-style-type:none;">
#     <br>
#   <center><li style="font-weight: bold;font-family:Trebuchet MS;font-size:20px;font-style: italic;color:  black">DATASET 2</li></center>
#   <center><li style="font-weight: bold;font-family:Trebuchet MS;font-size:30px;font-style: italic;color:  darkble">PRODUCT DESCRIPTION DATASET</li></center>
# </ul>
#     <br>
# </div>

# %%
productDescriptionsDf= pd.read_csv(r'../data/product_descriptions.csv', sep=';')
productDescriptionsDf.head(4)
# Out:
#   Articlenumber                                  Short description  \
# 0     S-1124F-A  STYcutter 1124F-A – unser Einstiegsmodell mit ...
# 1      S-1310-A                  STYcutter 1310-A – Der Allrounder
# 2    S-1310RW-A                STYcutter 1310RW-A – Der Allrounder
# 3    S-1310SD-A             STYcutter 1310SD-A – bewährte Qualität
#
#   Short description 2                                   Long description  \
# 0                 NaN  Die STYcutter 1124F-A – unser Einstiegsmodell ...
# 1                 NaN  Die STYcutter 1310  – Der Allrounder\n\n\nUm d...
# 2                 NaN  Die STYcutter 1310RW-A  – Der Allrounder\n\n\n...
# 3                 NaN  Um den Anforderungen der Verarbeiter gerecht z...
#
#   Language
# 0       de
# 1       de
# 2       de
# 3       de

# %%
productDescriptionsDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 470 entries, 0 to 469
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Articlenumber        470 non-null    object
#  1   Short description    466 non-null    object
#  2   Short description 2  143 non-null    object
#  3   Long description     418 non-null    object
#  4   Language             470 non-null    object
# dtypes: object(5)
# memory usage: 18.5+ KB

# %%
cleanProductDescriptionsDf = productDescriptionsDf.copy()

# %%
cleanProductDescriptionsDf = cleanBadValues(cleanProductDescriptionsDf, badValues)
# Out:
# No Bad values found!

# %%
cleanProductDescriptionsDf.isnull().sum()
# Out:
# Articlenumber            0
# Short description        4
# Short description 2    327
# Long description        52
# Language                 0
# dtype: int64

# %% [markdown]
# #### Data Quality Check for Join Key
#
# According to the assignment, all records used for joining must have a valid `Articlenumber` in the `product_descriptions` dataset.
# As shown above, the number of missing values in the `Articlenumber` column is zero.
#
# **Conclusion:**
# All records in `product_descriptions` have a valid `Articlenumber`. Therefore, no rows needed to be dropped for this join key requirement.

# %%
cleanProductDescriptionsDf.describe()
# Out:
#        Articlenumber                                  Short description  \
# count            470                                                466
# unique           430                                                439
# top        S-1124F-A  COX ELECTRAFLOW PLUS FLOORFIX 1800 ML KARTUSCH...
# freq               2                                                  3
#
#              Short description 2  \
# count                        143
# unique                       118
# top     GKS 18V-57-2 L (solo/ C)
# freq                           2
#
#                                          Long description Language
# count                                                 418      470
# unique                                                359        2
# top     Mit bürstenlosem Motor und QuickIN Schnittstel...       de
# freq                                                    6      430

# %%
cleanProductDescriptionsDf['Articlenumber'].duplicated().sum()
# Out:
# 40

# %%
duplicateCounts = cleanProductDescriptionsDf['Articlenumber'].value_counts()
duplicates = duplicateCounts[duplicateCounts > 1]
duplicates
# Out:
# Articlenumber
# S-1124F-A       2
# 0611914001      2
# 0611913000      2
# 503039          2
# P00M1-12V       2
# 06016A8109      2
# 06016C1200      2
# 06016C0000      2
# 06012B4001      2
# 0601620100      2
# 06014A6000      2
# 06019H6L01      2
# 06016B8000      2
# 06016B9000      2
# 06016C1100      2
# 06015B3001      2
# 06019L5000      2
# 06015B2001      2
# S-1310-A        2
# 06016B5000      2
# 06014A6200      2
# 0601B43000      2
# 06019H6100      2
# S-1310RW-A      2
# 06014A3100      2
# S-1310SD-A      2
# S-UL55-22-K     2
# S-UL55-22-KA    2
# A010.00115      2
# 06019J4002      2
# 06019H6000      2
# 06016B4000      2
# 06019H6400      2
# 06017B0100      2
# 0601372201      2
# 06012A0400      2
# 06019J7001      2
# 06019H6300      2
# 06019H9001      2
# 06019H5202      2
# Name: count, dtype: int64

# %%
dupes = cleanProductDescriptionsDf[cleanProductDescriptionsDf['Articlenumber'].duplicated(keep=False)]
dupes[['Articlenumber', 'Language']].sort_values('Articlenumber')
# Out:
#     Articlenumber Language
# 445    06012A0400       en
# 15     06012A0400       de
# 459    06012B4001       en
# 29     06012B4001       de
# 444    0601372201       en
# ..            ...      ...
# 433    S-1310SD-A       en
# 434   S-UL55-22-K       en
# 4     S-UL55-22-K       de
# 5    S-UL55-22-KA       de
# 435  S-UL55-22-KA       en
#
# [80 rows x 2 columns]

# %%
duplicatesAlongLanguage = cleanProductDescriptionsDf.duplicated(subset=['Articlenumber', 'Language'], keep=False)
print(cleanProductDescriptionsDf[duplicatesAlongLanguage])
# Out:
# Empty DataFrame
# Columns: [Articlenumber, Short description, Short description 2, Long description, Language]
# Index: []

# %% [markdown]
# #### Duplicate Check for `Articlenumber` in `product_descriptions`
#
# Upon checking for duplicate `Articlenumber` values, we found that all such cases are due to the presence of multiple language versions (e.g., 'de' and 'en') for the same product. Each `Articlenumber` appears only once per language, which is expected and correct for a multilingual product catalog.
#
# **Conclusion:**
# No rows were dropped for duplicated `Articlenumber` values, as these are not true duplicates but rather necessary multilingual entries.

# %%
cleanProductDescriptionsDf
# Out:
#     Articlenumber                                  Short description  \
# 0       S-1124F-A  STYcutter 1124F-A – unser Einstiegsmodell mit ...
# 1        S-1310-A                  STYcutter 1310-A – Der Allrounder
# 2      S-1310RW-A                STYcutter 1310RW-A – Der Allrounder
# 3      S-1310SD-A             STYcutter 1310SD-A – bewährte Qualität
# 4     S-UL55-22-K  STYcutter UL55-22-K im Koffer – wenn mobil, da...
# ..            ...                                                ...
# 465    06016B9000         Cordless circular saw BITURBO GKS 18V-70 L
# 466    06016C1100               Cordless circular saw GKS 18V-57-2 L
# 467    06015B3001                      Cordless jigsaw GST 18V-125 B
# 468    06019L5000   Cordless impact wrench GDS 18V-330 HC, in carton
# 469    06015B2001                      Cordless jigsaw GST 18V-125 S
#
#           Short description 2  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 465    GKS 18V-70 L (solo/ C)
# 466  GKS 18V-57-2 L (solo/ C)
# 467   GST 18V-125 B (solo/ C)
# 468  GDS 18V-330 HC (solo/ C)
# 469   GST 18V-125 S (solo/ C)
#
#                                       Long description Language
# 0    Die STYcutter 1124F-A – unser Einstiegsmodell ...       de
# 1    Die STYcutter 1310  – Der Allrounder\n\n\nUm d...       de
# 2    Die STYcutter 1310RW-A  – Der Allrounder\n\n\n...       de
# 3    Um den Anforderungen der Verarbeiter gerecht z...       de
# 4    Die STYcutter UL55-22-K – wenn mobil, dann ric...       de
# ..                                                 ...      ...
# 465                                                NaN       en
# 466                                                NaN       en
# 467                                                NaN       en
# 468                                                NaN       en
# 469                                                NaN       en
#
# [470 rows x 5 columns]

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <ul style="list-style-type:none;">
#     <br>
#   <center><li style="font-weight: bold;font-family:Trebuchet MS;font-size:20px;font-style: italic;color:  black">DATASET 3</li></center>
#   <center><li style="font-weight: bold;font-family:Trebuchet MS;font-size:30px;font-style: italic;color:  darkble">PRODUCT PROPERTIES DATASET</li></center>
# </ul>
#     <br>
# </div>

# %%
productPropertiesDf= pd.read_csv(r'../data/product_properties.csv', sep=';')
productPropertiesDf.head(4)
# Out:
#   Manufacturernumber Articlenumber  EAN  \
# 0                NaN     S-1124F-A  NaN
# 1                NaN      S-1310-A  NaN
# 2                NaN    S-1310RW-A  NaN
# 3                NaN    S-1310SD-A  NaN
#
#                                    Technical details  Product category  \
# 0  §Schnitthöhe§1130§mm|§Schnitttiefe§250§mm|§Geh...               NaN
# 1  §Schnitthöhe§1130§mm|§Schnitttiefe§310§mm|§Geh...               NaN
# 2  §Schnitthöhe§1130§mm|§Schnitttiefe§310§mm|§Geh...               NaN
# 3  §Schnitthöhe§1130§mm|§Schnitttiefe§310§mm|§Geh...               NaN
#
#    Technical specifications  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
#
#                               Picture normal reduced  Depth m  Width m  \
# 0  'https://www.nexmart.com/media/catalog/ampshar...     0.28     0.67
# 1  'https://www.nexmart.com/media/catalog/ampshar...     0.28     0.67
# 2  'https://www.nexmart.com/media/catalog/ampshar...     0.28     0.67
# 3  'https://www.nexmart.com/media/catalog/ampshar...     0.28     0.67
#
#    Length m  ...  Delivery time days  Type of product Price quantity  \
# 0       1.4  ...                 NaN              NaN              1
# 1       1.4  ...                 NaN              NaN              1
# 2       1.4  ...                 NaN              NaN              1
# 3       1.4  ...                 NaN              NaN              1
#
#    ETIM Features ETIM ECLASS Features  ECLASS  PROFICLASS Features  \
# 0            NaN  NaN             NaN     NaN                  NaN
# 1            NaN  NaN             NaN     NaN                  NaN
# 2            NaN  NaN             NaN     NaN                  NaN
# 3            NaN  NaN             NaN     NaN                  NaN
#
#    PROFICLASS  Product features
# 0         NaN               NaN
# 1         NaN               NaN
# 2         NaN               NaN
# 3         NaN               NaN
#
# [4 rows x 21 columns]

# %%
print('The Dataset contains {} rows & {} columns'.format(productPropertiesDf.shape[0],productPropertiesDf.shape[1]))
# Out:
# The Dataset contains 430 rows & 21 columns

# %%
productPropertiesDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430 entries, 0 to 429
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturernumber        285 non-null    object
#  1   Articlenumber             426 non-null    object
#  2   EAN                       342 non-null    float64
#  3   Technical details         400 non-null    object
#  4   Product category          0 non-null      float64
#  5   Technical specifications  0 non-null      float64
#  6   Picture normal reduced    430 non-null    object
#  7   Depth m                   370 non-null    float64
#  8   Width m                   372 non-null    float64
#  9   Length m                  370 non-null    float64
#  10  Weight kg                 425 non-null    float64
#  11  Delivery time days        4 non-null      float64
#  12  Type of product           218 non-null    object
#  13  Price quantity            430 non-null    int64
#  14  ETIM Features             44 non-null     object
#  15  ETIM                      44 non-null     object
#  16  ECLASS Features           0 non-null      float64
#  17  ECLASS                    0 non-null      float64
#  18  PROFICLASS Features       0 non-null      float64
#  19  PROFICLASS                0 non-null      float64
#  20  Product features          0 non-null      float64
# dtypes: float64(13), int64(1), object(7)
# memory usage: 70.7+ KB

# %%
cleanProductPropertiesDf=productPropertiesDf.copy()

# %%
cleanManufacturersDf = cleanBadValues(cleanProductPropertiesDf, badValues)
# Out:
# Bad values detected and replaced!

# %%
cleanProductPropertiesDf.isnull().sum()
# Out:
# Manufacturernumber          145
# Articlenumber                 4
# EAN                          88
# Technical details            30
# Product category            430
# Technical specifications    430
# Picture normal reduced        4
# Depth m                      60
# Width m                      58
# Length m                     60
# Weight kg                     5
# Delivery time days          426
# Type of product             212
# Price quantity                0
# ETIM Features               386
# ETIM                        386
# ECLASS Features             430
# ECLASS                      430
# PROFICLASS Features         430
# PROFICLASS                  430
# Product features            430
# dtype: int64

# %%
cleanProductPropertiesDf.dropna(subset=['Articlenumber','Manufacturernumber'], inplace=True)

# %%
cleanProductPropertiesDf = cleanProductPropertiesDf.dropna(axis=1, how='all')

# %% [markdown]
# Columns with only null values (no information for any product) were dropped prior to merging, as they do not contribute to the analysis and only add unnecessary clutter to the dataset.

# %%
cleanProductPropertiesDf.describe()
# Out:
#                 EAN     Depth m     Width m    Length m   Weight kg  \
# count  2.680000e+02  237.000000  237.000000  237.000000  277.000000
# mean   3.941612e+12    0.164012    0.307797    0.392705    6.153316
# std    2.612655e+11    0.091753    0.105786    0.164024    5.277181
# min    3.165141e+12    0.000000    0.000000    0.000000    0.350000
# 25%    4.012079e+12    0.102000    0.239000    0.325000    2.540000
# 50%    4.014587e+12    0.152000    0.357000    0.442000    5.372000
# 75%    4.059671e+12    0.234000    0.358000    0.445000    7.336000
# max    4.068708e+12    0.572000    0.588000    0.790000   32.700000
#
#        Delivery time days  Price quantity
# count                 4.0           281.0
# mean                  4.0             1.0
# std                   2.0             0.0
# min                   1.0             1.0
# 25%                   4.0             1.0
# 50%                   5.0             1.0
# 75%                   5.0             1.0
# max                   5.0             1.0

# %%
cleanProductPropertiesDf.duplicated(subset=['Articlenumber', 'Manufacturernumber']).sum()
# Out:
# 0

# %%
cleanProductPropertiesDf
# Out:
#     Manufacturernumber Articlenumber           EAN  \
# 7        0 601 6B4 000    06016B4000           NaN
# 8        0 601 9J4 002    06019J4002           NaN
# 9        0 601 9H6 000    06019H6000           NaN
# 10       0 601 9H6 100    06019H6100           NaN
# 11       0 601 9H6 300    06019H6300           NaN
# ..                 ...           ...           ...
# 327       LS100FLEXCFB  LS100FLEXCFB  4.012079e+12
# 328        LS50FLEXCFB   LS50FLEXCFB  4.012079e+12
# 329            RALB1EU       RALB1EU  4.012079e+12
# 330            RALB2EU       RALB2EU  4.012079e+12
# 331            RALB2US       RALB2US  4.012079e+12
#
#                                      Technical details  \
# 7    §Titel§Akku-Tauchsäge BITURBO GKT 18V-52 GC Pr...
# 8    §Titel§Akku-Winkelschleifer GWS 18V-10 Profess...
# 9    §Titel§Akku-Winkelschleifer BITURBO GWS 18V-15...
# 10   §Titel§Akku-Winkelschleifer BITURBO GWS 18V-15...
# 11   §Titel§Akku-Winkelschleifer BITURBO GWS 18V-15...
# ..                                                 ...
# 327  §Lochergrößen§152.4§mm|§Lochergrößen PG§48§|§L...
# 328  §Betätigungsart§akku-hydraulisch§|§Stanzkraft§...
# 329  §Nennspannung§18§V|§Kapazität§2§Ah|§Ausführung...
# 330  §Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung...
# 331  §Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung...
#
#                                 Picture normal reduced  Depth m  Width m  \
# 7    'https://www.nexmart.com/media/catalog/ampshar...    0.254     0.36
# 8    'https://www.nexmart.com/media/catalog/ampshar...    0.135     0.16
# 9    'https://www.nexmart.com/media/catalog/ampshar...    0.100     0.10
# 10   'https://www.nexmart.com/media/catalog/ampshar...    0.155     0.36
# 11   'https://www.nexmart.com/media/catalog/ampshar...    0.152     0.36
# ..                                                 ...      ...      ...
# 327                                                NaN      NaN      NaN
# 328  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
# 329  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
# 330  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
# 331  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
#
#      Length m  Weight kg  Delivery time days Type of product  Price quantity  \
# 7       0.444      4.032                 NaN    main_product               1
# 8       0.395      1.424                 NaN    main_product               1
# 9       0.150      2.300                 NaN    main_product               1
# 10      0.440      1.745                 NaN    main_product               1
# 11      0.442      1.780                 NaN    main_product               1
# ..        ...        ...                 ...             ...             ...
# 327       NaN      6.050                 NaN             NaN               1
# 328       NaN      5.500                 NaN             NaN               1
# 329       NaN      0.350                 NaN             NaN               1
# 330       NaN      0.640                 NaN             NaN               1
# 331       NaN      0.640                 NaN             NaN               1
#
#                                          ETIM Features      ETIM
# 7                                                  NaN       NaN
# 8                                                  NaN       NaN
# 9                                                  NaN       NaN
# 10                                                 NaN       NaN
# 11                                                 NaN       NaN
# ..                                                 ...       ...
# 327  §Lochergrößen§152.4§§|§Lochergrößen PG§48§§|§L...  EC002121
# 328  §Betätigungsart§akku-hydraulisch§§|§Stanzkraft...  EC001085
# 329  §Nennspannung§18§§|§Kapazität§2§§|§Ausführung§...  EC001199
# 330  §Nennspannung§18§§|§Kapazität§5§§|§Ausführung§...  EC001199
# 331  §Nennspannung§18§§|§Kapazität§5§§|§Ausführung§...  EC001199
#
# [281 rows x 14 columns]

# %% [markdown]
# We first join `product_properties` with `product_descriptions` on `Articlenumber` to combine product details and descriptions.
# Then, we join this result with `manufacturers` on `Manufacturernumber` to add manufacturer information.
# This ensures all required join keys are present and no data is lost due to missing references.

# %%
mergedDf = cleanProductPropertiesDf.merge(cleanProductDescriptionsDf, on='Articlenumber', how='inner')
mergedDf.shape
# Out:
# (308, 18)

# %%
finalDf = mergedDf.merge(manufacturersDf, on='Manufacturernumber', how='inner')
finalDf.shape
# Out:
# (308, 19)

# %%
finalDf.head(2).style.background_gradient(cmap='Pastel1')
# Out:
# <style type="text/css">
# #T_edaac_row0_col2, #T_edaac_row0_col9, #T_edaac_row1_col2, #T_edaac_row1_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_edaac_row0_col5, #T_edaac_row0_col6, #T_edaac_row0_col7, #T_edaac_row0_col8, #T_edaac_row0_col11, #T_edaac_row1_col5, #T_edaac_row1_col6, #T_edaac_row1_col7, #T_edaac_row1_col8, #T_edaac_row1_col11 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# </style>
# <table id="T_edaac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edaac_level0_col0" class="col_heading level0 col0" >Manufacturernumber</th>
#       <th id="T_edaac_level0_col1" class="col_heading level0 col1" >Articlenumber</th>
#       <th id="T_edaac_level0_col2" class="col_heading level0 col2" >EAN</th>
#       <th id="T_edaac_level0_col3" class="col_heading level0 col3" >Technical details</th>
#       <th id="T_edaac_level0_col4" class="col_heading level0 col4" >Picture normal reduced</th>
#       <th id="T_edaac_level0_col5" class="col_heading level0 col5" >Depth m</th>
#       <th id="T_edaac_level0_col6" class="col_heading level0 col6" >Width m</th>
#       <th id="T_edaac_level0_col7" class="col_heading level0 col7" >Length m</th>
#       <th id="T_edaac_level0_col8" class="col_heading level0 col8" >Weight kg</th>
#       <th id="T_edaac_level0_col9" class="col_heading level0 col9" >Delivery time days</th>
#       <th id="T_edaac_level0_col10" class="col_heading level0 col10" >Type of product</th>
#       <th id="T_edaac_level0_col11" class="col_heading level0 col11" >Price quantity</th>
#       <th id="T_edaac_level0_col12" class="col_heading level0 col12" >ETIM Features</th>
#       <th id="T_edaac_level0_col13" class="col_heading level0 col13" >ETIM</th>
#       <th id="T_edaac_level0_col14" class="col_heading level0 col14" >Short description</th>
#       <th id="T_edaac_level0_col15" class="col_heading level0 col15" >Short description 2</th>
#       <th id="T_edaac_level0_col16" class="col_heading level0 col16" >Long description</th>
#       <th id="T_edaac_level0_col17" class="col_heading level0 col17" >Language</th>
#       <th id="T_edaac_level0_col18" class="col_heading level0 col18" >Manufacturername</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edaac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edaac_row0_col0" class="data row0 col0" >0 601 6B4 000</td>
#       <td id="T_edaac_row0_col1" class="data row0 col1" >06016B4000</td>
#       <td id="T_edaac_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_edaac_row0_col3" class="data row0 col3" >§Titel§Akku-Tauchsäge BITURBO GKT 18V-52 GC Professional§|§Neuheit bis§01.08.2020§|§SOL Datum§01.05.2020§|§Verpackungsabmessungen (Breite)§360§mm|§Verpackungsabmessungen (Länge)§444§mm|§Verpackungsabmessungen (Höhe)§254§mm|§Verpackungsabmessungen (Breite x Länge x Höhe)§360 x 444 x 254§mm|§Akkuspannung§18,0 V§|§Sägeblattbohrungs-Ø§20§mm|§Leerlaufdrehzahl, von§2.800§min-1|§Leerlaufdrehzahl, bis zu§5.500§min-1|§Leerlaufdrehzahl§2.800 – 5.500§min-1|§Gewicht exkl. Akku§4,1§kg|§Sägeblattdurchmesser§140§mm|§Führungsplatte (Länge)§305§mm|§Führungsplatte (Breite)§169§mm|§Führungsplatte§305 x 169§mm|§Neigungswinkel, von§-1§°|§Neigungswinkel, bis§47§°|§Neigungswinkel§-1 - 47§°|§Werkzeugabmessungen (Breite)§209§mm|§Werkzeugabmessungen (Länge)§374§mm|§Werkzeugabmessungen (Höhe)§234§mm|§Schnitttiefe ohne Führungsschiene (90°)§52§mm|§Schnitttiefe mit Führungsschiene (90°)§46§mm|§Schnitttiefe ohne Führungsschiene (45°)§32§mm|§Schnitttiefe mit Führungsschiene (45°)§32§mm|§Unterteilung der Produktkategorien§Akku-Tauchsäge BITURBO§</td>
#       <td id="T_edaac_row0_col4" class="data row0 col4" >'https://www.nexmart.com/media/catalog/ampshare/bosch/img-rd-298552-117_jpg/detail.jpg/normal.jpg</td>
#       <td id="T_edaac_row0_col5" class="data row0 col5" >0.254000</td>
#       <td id="T_edaac_row0_col6" class="data row0 col6" >0.360000</td>
#       <td id="T_edaac_row0_col7" class="data row0 col7" >0.444000</td>
#       <td id="T_edaac_row0_col8" class="data row0 col8" >4.032000</td>
#       <td id="T_edaac_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_edaac_row0_col10" class="data row0 col10" >main_product</td>
#       <td id="T_edaac_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_edaac_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_edaac_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_edaac_row0_col14" class="data row0 col14" >Akku-Tauchsäge BITURBO GKT 18V-52 GC in L-BOXX</td>
#       <td id="T_edaac_row0_col15" class="data row0 col15" >GKT 18V-52 GC (L) solo CLC</td>
#       <td id="T_edaac_row0_col16" class="data row0 col16" >Akku-Tauchsäge BITURBO GKT 18V-52 GC, Die Akku-Tauchsäge GKT 18V-52 GC Professional aus dem 18V-Sortiment von Bosch bietet die Leistung eines Netzgeräts und ist extrem kompakt. Ihre innovative BITURBO Brushless-Technologie mit bürstenlosem Hochleistungsmotor und ProCORE18V liefert maximale kabellose Schnittleistung auf demselben Niveau wie entsprechende kabelgebundene Tauchsägen mit 1.620 Watt. Dank ihres einzigartigen kompakten Designs, das den Betrieb mit nur einem Akku ermöglicht, bietet die Säge höchste Mobilität. Ihre sehr kompakte Bauform ermöglicht einen minimalen Abstand von nur 10 mm zwischen Sägeblatt und Wand. Diese Tauchsäge eignet sich für Tauchschnitte in Holz, Holzverbundwerkstoffen, Platten und Plattenwerkstoffen sowie in Aluminium und Acrylglas. Es kann mit Staubsack verwendet werden und ist kompatibel mit dem Bosch Click & Clean System und den Führungsschienensystemen von Bosch, Festool, Mafell und Makita sowie mit allen Bosch Professional 18V-Akkus und -Ladegeräten (Professional 18V System). Für maximale Leistung ProCORE18V ≥ 5,5 Ah verwenden. Auch kompatibel mit AMPShare, der markenübergreifenden Akku-Allianz. Die GKT 18V-52 GC Professional zeichnet sich zudem durch konstante Drehzahl, Eco-Modus für eine bis zu 20 % längere Laufzeit, HMI, individuelle Drehzahleinstellung per App, Überlastschutz, Wiederanlaufschutz, Sanftanlauf und Spindelarretierung aus. 1 x Kreissägeblatt, Expert for Wood für Akku-Sägen, 140 x 1,8/1,3 x 20 mm, 42 (2 608 644 500). L-BOXX 238 (1 600 A01 2G2). Staubbeutel (2 608 000 696). 1 x Bluetooth Low Energy Modul GCY 42 Professional (1 600 A01 3WF). Innensechskantschlüssel</td>
#       <td id="T_edaac_row0_col17" class="data row0 col17" >de</td>
#       <td id="T_edaac_row0_col18" class="data row0 col18" >BOSCH</td>
#     </tr>
#     <tr>
#       <th id="T_edaac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_edaac_row1_col0" class="data row1 col0" >0 601 6B4 000</td>
#       <td id="T_edaac_row1_col1" class="data row1 col1" >06016B4000</td>
#       <td id="T_edaac_row1_col2" class="data row1 col2" >nan</td>
#       <td id="T_edaac_row1_col3" class="data row1 col3" >§Titel§Akku-Tauchsäge BITURBO GKT 18V-52 GC Professional§|§Neuheit bis§01.08.2020§|§SOL Datum§01.05.2020§|§Verpackungsabmessungen (Breite)§360§mm|§Verpackungsabmessungen (Länge)§444§mm|§Verpackungsabmessungen (Höhe)§254§mm|§Verpackungsabmessungen (Breite x Länge x Höhe)§360 x 444 x 254§mm|§Akkuspannung§18,0 V§|§Sägeblattbohrungs-Ø§20§mm|§Leerlaufdrehzahl, von§2.800§min-1|§Leerlaufdrehzahl, bis zu§5.500§min-1|§Leerlaufdrehzahl§2.800 – 5.500§min-1|§Gewicht exkl. Akku§4,1§kg|§Sägeblattdurchmesser§140§mm|§Führungsplatte (Länge)§305§mm|§Führungsplatte (Breite)§169§mm|§Führungsplatte§305 x 169§mm|§Neigungswinkel, von§-1§°|§Neigungswinkel, bis§47§°|§Neigungswinkel§-1 - 47§°|§Werkzeugabmessungen (Breite)§209§mm|§Werkzeugabmessungen (Länge)§374§mm|§Werkzeugabmessungen (Höhe)§234§mm|§Schnitttiefe ohne Führungsschiene (90°)§52§mm|§Schnitttiefe mit Führungsschiene (90°)§46§mm|§Schnitttiefe ohne Führungsschiene (45°)§32§mm|§Schnitttiefe mit Führungsschiene (45°)§32§mm|§Unterteilung der Produktkategorien§Akku-Tauchsäge BITURBO§</td>
#       <td id="T_edaac_row1_col4" class="data row1 col4" >'https://www.nexmart.com/media/catalog/ampshare/bosch/img-rd-298552-117_jpg/detail.jpg/normal.jpg</td>
#       <td id="T_e

# %%
finalDf.tail(2).style.background_gradient(cmap='Pastel1')
# Out:
# <style type="text/css">
# #T_a3246_row0_col2, #T_a3246_row0_col8, #T_a3246_row0_col11, #T_a3246_row1_col8, #T_a3246_row1_col11 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_a3246_row0_col5, #T_a3246_row0_col6, #T_a3246_row0_col7, #T_a3246_row0_col9, #T_a3246_row1_col5, #T_a3246_row1_col6, #T_a3246_row1_col7, #T_a3246_row1_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a3246_row1_col2 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# </style>
# <table id="T_a3246">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3246_level0_col0" class="col_heading level0 col0" >Manufacturernumber</th>
#       <th id="T_a3246_level0_col1" class="col_heading level0 col1" >Articlenumber</th>
#       <th id="T_a3246_level0_col2" class="col_heading level0 col2" >EAN</th>
#       <th id="T_a3246_level0_col3" class="col_heading level0 col3" >Technical details</th>
#       <th id="T_a3246_level0_col4" class="col_heading level0 col4" >Picture normal reduced</th>
#       <th id="T_a3246_level0_col5" class="col_heading level0 col5" >Depth m</th>
#       <th id="T_a3246_level0_col6" class="col_heading level0 col6" >Width m</th>
#       <th id="T_a3246_level0_col7" class="col_heading level0 col7" >Length m</th>
#       <th id="T_a3246_level0_col8" class="col_heading level0 col8" >Weight kg</th>
#       <th id="T_a3246_level0_col9" class="col_heading level0 col9" >Delivery time days</th>
#       <th id="T_a3246_level0_col10" class="col_heading level0 col10" >Type of product</th>
#       <th id="T_a3246_level0_col11" class="col_heading level0 col11" >Price quantity</th>
#       <th id="T_a3246_level0_col12" class="col_heading level0 col12" >ETIM Features</th>
#       <th id="T_a3246_level0_col13" class="col_heading level0 col13" >ETIM</th>
#       <th id="T_a3246_level0_col14" class="col_heading level0 col14" >Short description</th>
#       <th id="T_a3246_level0_col15" class="col_heading level0 col15" >Short description 2</th>
#       <th id="T_a3246_level0_col16" class="col_heading level0 col16" >Long description</th>
#       <th id="T_a3246_level0_col17" class="col_heading level0 col17" >Language</th>
#       <th id="T_a3246_level0_col18" class="col_heading level0 col18" >Manufacturername</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3246_level0_row0" class="row_heading level0 row0" >306</th>
#       <td id="T_a3246_row0_col0" class="data row0 col0" >RALB2EU</td>
#       <td id="T_a3246_row0_col1" class="data row0 col1" >RALB2EU</td>
#       <td id="T_a3246_row0_col2" class="data row0 col2" >4012078866842.000000</td>
#       <td id="T_a3246_row0_col3" class="data row0 col3" >§Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung§Lithium-Ionen§|§Gewicht§635§g</td>
#       <td id="T_a3246_row0_col4" class="data row0 col4" >'https://www.nexmart.com/media/catalog/ampshare/klauke/ralb2eu_jpg/detail.jpg/normal.jpg</td>
#       <td id="T_a3246_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_a3246_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_a3246_row0_col7" class="data row0 col7" >nan</td>
#       <td id="T_a3246_row0_col8" class="data row0 col8" >0.640000</td>
#       <td id="T_a3246_row0_col9" class="data row0 col9" >nan</td>
#       <td id="T_a3246_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_a3246_row0_col11" class="data row0 col11" >1</td>
#       <td id="T_a3246_row0_col12" class="data row0 col12" >§Nennspannung§18§§|§Kapazität§5§§|§Ausführung§Lithium-Ionen§§|§Gewicht§635§§</td>
#       <td id="T_a3246_row0_col13" class="data row0 col13" >EC001199</td>
#       <td id="T_a3246_row0_col14" class="data row0 col14" >Akku Li-Ion Bosch, 18V/5Ah</td>
#       <td id="T_a3246_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_a3246_row0_col16" class="data row0 col16" >Bosch Li-Ion Akku 18V/5Ah Akku, geeignet für die Verwendung im EU-Raum in Verbindung mit dem Ladegerät LGLB1EU</td>
#       <td id="T_a3246_row0_col17" class="data row0 col17" >de</td>
#       <td id="T_a3246_row0_col18" class="data row0 col18" >BOSCH</td>
#     </tr>
#     <tr>
#       <th id="T_a3246_level0_row1" class="row_heading level0 row1" >307</th>
#       <td id="T_a3246_row1_col0" class="data row1 col0" >RALB2US</td>
#       <td id="T_a3246_row1_col1" class="data row1 col1" >RALB2US</td>
#       <td id="T_a3246_row1_col2" class="data row1 col2" >4012078868662.000000</td>
#       <td id="T_a3246_row1_col3" class="data row1 col3" >§Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung§Lithium-Ionen§|§Gewicht§635§g</td>
#       <td id="T_a3246_row1_col4" class="data row1 col4" >'https://www.nexmart.com/media/catalog/ampshare/klauke/ralb2eu_jpg/detail.jpg/normal.jpg</td>
#       <td id="T_a3246_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_a3246_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_a3246_row1_col7" class="data row1 col7" >nan</td>
#       <td id="T_a3246_row1_col8" class="data row1 col8" >0.640000</td>
#       <td id="T_a3246_row1_col9" class="data row1 col9" >nan</td>
#       <td id="T_a3246_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_a3246_row1_col11" class="data row1 col11" >1</td>
#       <td id="T_a3246_row1_col12" class="data row1 col12" >§Nennspannung§18§§|§Kapazität§5§§|§Ausführung§Lithium-Ionen§§|§Gewicht§635§§</td>
#       <td id="T_a3246_row1_col13" class="data row1 col13" >EC001199</td>
#       <td id="T_a3246_row1_col14" class="data row1 col14" >Bosch Akku Li-Ion</td>
#       <td id="T_a3246_row1_col15" class="data row1 col15" >nan</td>
#       <td id="T_a3246_row1_col16" class="data row1 col16" >Bosch Akku 18V /5,0 Ah Li-Ion 1607A3502E</td>
#       <td id="T_a3246_row1_col17" class="data row1 col17" >de</td>
#       <td id="T_a3246_row1_col18" class="data row1 col18" >BOSCH</td>
#     </tr>
#   </tbody>
# </table>

# %%
print('The Dataset contains {} rows & {} columns'.format(finalDf.shape[0],finalDf.shape[1]))
# Out:
# The Dataset contains 308 rows & 19 columns

# %%
finalDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Manufacturernumber      308 non-null    object
#  1   Articlenumber           308 non-null    object
#  2   EAN                     282 non-null    float64
#  3   Technical details       304 non-null    object
#  4   Picture normal reduced  304 non-null    object
#  5   Depth m                 264 non-null    float64
#  6   Width m                 264 non-null    float64
#  7   Length m                264 non-null    float64
#  8   Weight kg               304 non-null    float64
#  9   Delivery time days      4 non-null      float64
#  10  Type of product         241 non-null    object
#  11  Price quantity          308 non-null    int64
#  12  ETIM Features           44 non-null     object
#  13  ETIM                    44 non-null     object
#  14  Short description       304 non-null    object
#  15  Short description 2     137 non-null    object
#  16  Long description        280 non-null    object
#  17  Language                308 non-null    object
#  18  Manufacturername        308 non-null    object
# dtypes: float64(6), int64(1), object(12)
# memory usage: 45.8+ KB

# %%
finalDf.isnull().sum()
# Out:
# Manufacturernumber          0
# Articlenumber               0
# EAN                        26
# Technical details           4
# Picture normal reduced      4
# Depth m                    44
# Width m                    44
# Length m                   44
# Weight kg                   4
# Delivery time days        304
# Type of product            67
# Price quantity              0
# ETIM Features             264
# ETIM                      264
# Short description           4
# Short description 2       171
# Long description           28
# Language                    0
# Manufacturername            0
# dtype: int64

# %%
# Filter out numeric columns only
numericData = finalDf.select_dtypes(include='number').columns.tolist()

# Get descriptive statistics for numeric data
finalDfDescriptiveStatics = finalDf[numericData].describe().T

# Add median to the descriptive statistics
finalDfDescriptiveStatics['median'] = finalDf[numericData].median().T

# Add mode to the descriptive statistics (taking the first mode, if multiple modes exist)
finalDfDescriptiveStatics['mode'] = finalDf[numericData].mode().iloc[0]

# Add range (difference between max and min values) to the descriptive statistics
finalDfDescriptiveStatics['range'] = (finalDfDescriptiveStatics['max'] - finalDfDescriptiveStatics['min']).T

# Display the final descriptive statistics
finalDfDescriptiveStatics.T.style.background_gradient(cmap='Pastel2')
# Out:
# <style type="text/css">
# #T_4692d_row0_col0, #T_4692d_row1_col1, #T_4692d_row1_col2, #T_4692d_row1_col3, #T_4692d_row1_col4, #T_4692d_row1_col6, #T_4692d_row2_col0, #T_4692d_row2_col1, #T_4692d_row2_col2, #T_4692d_row2_col3, #T_4692d_row2_col4, #T_4692d_row2_col6, #T_4692d_row3_col1, #T_4692d_row3_col2, #T_4692d_row3_col3, #T_4692d_row3_col4, #T_4692d_row3_col5, #T_4692d_row3_col6, #T_4692d_row4_col1, #T_4692d_row4_col2, #T_4692d_row4_col3, #T_4692d_row4_col4, #T_4692d_row4_col6, #T_4692d_row5_col1, #T_4692d_row5_col2, #T_4692d_row5_col3, #T_4692d_row5_col4, #T_4692d_row5_col6, #T_4692d_row6_col1, #T_4692d_row6_col2, #T_4692d_row6_col3, #T_4692d_row6_col4, #T_4692d_row6_col6, #T_4692d_row7_col1, #T_4692d_row7_col2, #T_4692d_row7_col3, #T_4692d_row7_col4, #T_4692d_row7_col6, #T_4692d_row8_col1, #T_4692d_row8_col2, #T_4692d_row8_col3, #T_4692d_row8_col4, #T_4692d_row8_col6, #T_4692d_row9_col1, #T_4692d_row9_col2, #T_4692d_row9_col3, #T_4692d_row9_col4, #T_4692d_row9_col6, #T_4692d_row10_col1, #T_4692d_row10_col2, #T_4692d_row10_col3, #T_4692d_row10_col4, #T_4692d_row10_col6 {
#   background-color: #b3e2cd;
#   color: #000000;
# }
# #T_4692d_row0_col1, #T_4692d_row0_col2, #T_4692d_row0_col3, #T_4692d_row0_col4, #T_4692d_row0_col6, #T_4692d_row1_col0, #T_4692d_row4_col0, #T_4692d_row5_col0, #T_4692d_row5_col5, #T_4692d_row6_col0, #T_4692d_row6_col5, #T_4692d_row7_col0, #T_4692d_row7_col5, #T_4692d_row8_col0, #T_4692d_row8_col5, #T_4692d_row9_col5 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_4692d_row0_col5, #T_4692d_row1_col5, #T_4692d_row3_col0, #T_4692d_row4_col5, #T_4692d_row9_col0, #T_4692d_row10_col5 {
#   background-color: #f1e2cc;
#   color: #000000;
# }
# #T_4692d_row2_col5 {
#   background-color: #cbd5e8;
#   color: #000000;
# }
# #T_4692d_row10_col0 {
#   background-color: #fdcdac;
#   color: #000000;
# }
# </style>
# <table id="T_4692d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4692d_level0_col0" class="col_heading level0 col0" >EAN</th>
#       <th id="T_4692d_level0_col1" class="col_heading level0 col1" >Depth m</th>
#       <th id="T_4692d_level0_col2" class="col_heading level0 col2" >Width m</th>
#       <th id="T_4692d_level0_col3" class="col_heading level0 col3" >Length m</th>
#       <th id="T_4692d_level0_col4" class="col_heading level0 col4" >Weight kg</th>
#       <th id="T_4692d_level0_col5" class="col_heading level0 col5" >Delivery time days</th>
#       <th id="T_4692d_level0_col6" class="col_heading level0 col6" >Price quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4692d_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_4692d_row0_col0" class="data row0 col0" >282.000000</td>
#       <td id="T_4692d_row0_col1" class="data row0 col1" >264.000000</td>
#       <td id="T_4692d_row0_col2" class="data row0 col2" >264.000000</td>
#       <td id="T_4692d_row0_col3" class="data row0 col3" >264.000000</td>
#       <td id="T_4692d_row0_col4" class="data row0 col4" >304.000000</td>
#       <td id="T_4692d_row0_col5" class="data row0 col5" >4.000000</td>
#       <td id="T_4692d_row0_col6" class="data row0 col6" >308.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_4692d_row1_col0" class="data row1 col0" >3941071603107.021484</td>
#       <td id="T_4692d_row1_col1" class="data row1 col1" >0.167594</td>
#       <td id="T_4692d_row1_col2" class="data row1 col2" >0.303424</td>
#       <td id="T_4692d_row1_col3" class="data row1 col3" >0.396186</td>
#       <td id="T_4692d_row1_col4" class="data row1 col4" >5.987311</td>
#       <td id="T_4692d_row1_col5" class="data row1 col5" >4.000000</td>
#       <td id="T_4692d_row1_col6" class="data row1 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_4692d_row2_col0" class="data row2 col0" >264067561915.906189</td>
#       <td id="T_4692d_row2_col1" class="data row2 col1" >0.094509</td>
#       <td id="T_4692d_row2_col2" class="data row2 col2" >0.107311</td>
#       <td id="T_4692d_row2_col3" class="data row2 col3" >0.160669</td>
#       <td id="T_4692d_row2_col4" class="data row2 col4" >5.360854</td>
#       <td id="T_4692d_row2_col5" class="data row2 col5" >2.000000</td>
#       <td id="T_4692d_row2_col6" class="data row2 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_4692d_row3_col0" class="data row3 col0" >3165140508940.000000</td>
#       <td id="T_4692d_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_4692d_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_4692d_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_4692d_row3_col4" class="data row3 col4" >0.350000</td>
#       <td id="T_4692d_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_4692d_row3_col6" class="data row3 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_4692d_row4_col0" class="data row4 col0" >4012078883620.000000</td>
#       <td id="T_4692d_row4_col1" class="data row4 col1" >0.108000</td>
#       <td id="T_4692d_row4_col2" class="data row4 col2" >0.229500</td>
#       <td id="T_4692d_row4_col3" class="data row4 col3" >0.334750</td>
#       <td id="T_4692d_row4_col4" class="data row4 col4" >2.300000</td>
#       <td id="T_4692d_row4_col5" class="data row4 col5" >4.000000</td>
#       <td id="T_4692d_row4_col6" class="data row4 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_4692d_row5_col0" class="data row5 col0" >4014586899198.000000</td>
#       <td id="T_4692d_row5_col1" class="data row5 col1" >0.152000</td>
#       <td id="T_4692d_row5_col2" class="data row5 col2" >0.357000</td>
#       <td id="T_4692d_row5_col3" class="data row5 col3" >0.442000</td>
#       <td id="T_4692d_row5_col4" class="data row5 col4" >5.039500</td>
#       <td id="T_4692d_row5_col5" class="data row5 col5" >5.000000</td>
#       <td id="T_4692d_row5_col6" class="data row5 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_4692d_row6_col0" class="data row6 col0" >4059952510229.250000</td>
#       <td id="T_4692d_row6_col1" class="data row6 col1" >0.234000</td>
#       <td id="T_4692d_row6_col2" class="data row6 col2" >0.358000</td>
#       <td id="T_4692d_row6_col3" class="data row6 col3" >0.445000</td>
#       <td id="T_4692d_row6_col4" class="data row6 col4" >7.030000</td>
#       <td id="T_4692d_row6_col5" class="data row6 col5" >5.000000</td>
#       <td id="T_4692d_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_4692d_row7_col0" class="data row7 col0" >4068708005556.000000</td>
#       <td id="T_4692d_row7_col1" class="data row7 col1" >0.572000</td>
#       <td id="T_4692d_row7_col2" class="data row7 col2" >0.588000</td>
#       <td id="T_4692d_row7_col3" class="data row7 col3" >0.790000</td>
#       <td id="T_4692d_row7_col4" class="data row7 col4" >32.700000</td>
#       <td id="T_4692d_row7_col5" class="data row7 col5" >5.000000</td>
#       <td id="T_4692d_row7_col6" class="data row7 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4692d_level0_row8" class="row_heading level0 row8" >median</th>
#       <td id="T_4692d_row8_col0" class="data row8 col0" >4014586899198.000000</td>
#       <td id="T_4692d_row8_col1" class="data row8 col1" >0.152000</td>
#       <td id="T_4692d_row8_col2" class="data row8 col2" >0.357000</td>
#       <td id="T_4692d_row8_col3" class="data row8 col3" >0.442000</td>
#       <td id="T_4692d_row8_col4" class="data row8 col4" >5.039500</td>
#       <td id="T_4692d_row8_col5" class="data row8 col5" >5.000000</td>
#       <td id="T_4692d_row8_col6" class="data row8 col6" >1.000000</td>
#     </tr>
#     <tr>
#       <th i

# %%
engineeredDf = finalDf.copy()

# %%
def categorizeQuality(data):
    if pd.isnull(data):
        return 'bad'
    return 'good'

totalGood = []
totalBad = []

for index, row in engineeredDf.iterrows():
    goodCount = 0
    badCount = 0
    
    for col in engineeredDf.columns[2:]: 
        
        if categorizeQuality(row[col]) == 'good':
            goodCount += 1
        else:
            badCount += 1

    totalGood.append(goodCount)
    totalBad.append(badCount)

engineeredDf['total_good'] = totalGood
engineeredDf['total_bad'] = totalBad

# %%
def addEngineeredFeatures(df):

    # Feature: Count of products per manufacturer
    manu_counts = df['Manufacturername'].value_counts()
    df['Manufacturer_product_count'] = df['Manufacturername'].map(manu_counts)

    df['Product_length_category'] = pd.cut(df['Length m'], bins=[0, 0.3, 0.5, 1.0], labels=['Small', 'Medium', 'Large'])

    # Feature: Product volume in cubic meters (if all dims are available)
    df['Volume_m3'] = df[['Depth m', 'Width m', 'Length m']].prod(axis=1)

    # Feature: Length of long description
    df['Description_length'] = df['Long description'].fillna('').apply(len)

    return df

# %%
engineeredDf = addEngineeredFeatures(engineeredDf)

# %%
engineeredDf
# Out:
#     Manufacturernumber Articlenumber           EAN  \
# 0        0 601 6B4 000    06016B4000           NaN
# 1        0 601 6B4 000    06016B4000           NaN
# 2        0 601 9J4 002    06019J4002           NaN
# 3        0 601 9J4 002    06019J4002           NaN
# 4        0 601 9H6 000    06019H6000           NaN
# ..                 ...           ...           ...
# 303       LS100FLEXCFB  LS100FLEXCFB  4.012079e+12
# 304        LS50FLEXCFB   LS50FLEXCFB  4.012079e+12
# 305            RALB1EU       RALB1EU  4.012079e+12
# 306            RALB2EU       RALB2EU  4.012079e+12
# 307            RALB2US       RALB2US  4.012079e+12
#
#                                      Technical details  \
# 0    §Titel§Akku-Tauchsäge BITURBO GKT 18V-52 GC Pr...
# 1    §Titel§Akku-Tauchsäge BITURBO GKT 18V-52 GC Pr...
# 2    §Titel§Akku-Winkelschleifer GWS 18V-10 Profess...
# 3    §Titel§Akku-Winkelschleifer GWS 18V-10 Profess...
# 4    §Titel§Akku-Winkelschleifer BITURBO GWS 18V-15...
# ..                                                 ...
# 303  §Lochergrößen§152.4§mm|§Lochergrößen PG§48§|§L...
# 304  §Betätigungsart§akku-hydraulisch§|§Stanzkraft§...
# 305  §Nennspannung§18§V|§Kapazität§2§Ah|§Ausführung...
# 306  §Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung...
# 307  §Nennspannung§18§V|§Kapazität§5§Ah|§Ausführung...
#
#                                 Picture normal reduced  Depth m  Width m  \
# 0    'https://www.nexmart.com/media/catalog/ampshar...    0.254     0.36
# 1    'https://www.nexmart.com/media/catalog/ampshar...    0.254     0.36
# 2    'https://www.nexmart.com/media/catalog/ampshar...    0.135     0.16
# 3    'https://www.nexmart.com/media/catalog/ampshar...    0.135     0.16
# 4    'https://www.nexmart.com/media/catalog/ampshar...    0.100     0.10
# ..                                                 ...      ...      ...
# 303                                                NaN      NaN      NaN
# 304  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
# 305  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
# 306  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
# 307  'https://www.nexmart.com/media/catalog/ampshar...      NaN      NaN
#
#      Length m  Weight kg  Delivery time days  ...  \
# 0       0.444      4.032                 NaN  ...
# 1       0.444      4.032                 NaN  ...
# 2       0.395      1.424                 NaN  ...
# 3       0.395      1.424                 NaN  ...
# 4       0.150      2.300                 NaN  ...
# ..        ...        ...                 ...  ...
# 303       NaN      6.050                 NaN  ...
# 304       NaN      5.500                 NaN  ...
# 305       NaN      0.350                 NaN  ...
# 306       NaN      0.640                 NaN  ...
# 307       NaN      0.640                 NaN  ...
#
#                   Short description 2  \
# 0          GKT 18V-52 GC (L) solo CLC
# 1                                 NaN
# 2          GWS 18V-10 (C, 125 mm) CLC
# 3          GWS 18V-10 (C, 125 mm) CLC
# 4    GWS 18V-15 C 125 mm (L) solo CLC
# ..                                ...
# 303                               NaN
# 304                               NaN
# 305                               NaN
# 306                               NaN
# 307                               NaN
#
#                                       Long description Language  \
# 0    Akku-Tauchsäge BITURBO GKT 18V-52 GC, Die Akku...       de
# 1                                                  NaN       en
# 2    Akku-Winkelschleifer GWS 18V-10, Der kleine Ak...       de
# 3                                                  NaN       en
# 4    Akku-Winkelschleifer BITURBO GWS 18V-15 C, Der...       de
# ..                                                 ...      ...
# 303  LS 100 FLEX Akkuhydraulisches Stanzwerkzeug, h...       de
# 304  Akkuhydraulisches Stanzwerkzeug, hohe Flexibil...       de
# 305  Bosch Li-Ion Akku 18V/2Ah Akku, geeignet für d...       de
# 306  Bosch Li-Ion Akku 18V/5Ah Akku, geeignet für d...       de
# 307           Bosch Akku 18V /5,0 Ah Li-Ion 1607A3502E       de
#
#        Manufacturername total_good total_bad Manufacturer_product_count  \
# 0                 BOSCH         19         4                        140
# 1                 BOSCH         17         6                        140
# 2                 BOSCH         19         4                        140
# 3                 BOSCH         17         6                        140
# 4                 BOSCH         19         4                        140
# ..                  ...        ...       ...                        ...
# 303  GUSTAV KLAUKE GMBH         15         8                         40
# 304  GUSTAV KLAUKE GMBH         16         7                         40
# 305               BOSCH         16         7                        140
# 306               BOSCH         16         7                        140
# 307               BOSCH         16         7                        140
#
#     Product_length_category Volume_m3  Description_length
# 0                    Medium  0.040599                1640
# 1                    Medium  0.040599                   0
# 2                    Medium  0.008532                1087
# 3                    Medium  0.008532                   0
# 4                     Small  0.001500                1371
# ..                      ...       ...                 ...
# 303                     NaN  1.000000                 246
# 304                     NaN  1.000000                 636
# 305                     NaN  1.000000                 110
# 306                     NaN  1.000000                 110
# 307                     NaN  1.000000                  40
#
# [308 rows x 25 columns]

# %%
def plotFrequencyGridSmart(df, cols=None, nCols=6, figHeightPerRow=4, figWidthPerPlot=2.5, title=None, maxStrLen=20, maxUniqueFrac=0.5):
    if cols is None:
        cols = df.columns.tolist()

    usableCols = []
    for col in cols:
        if df[col].dtype == 'O' or pd.api.types.is_string_dtype(df[col]):
            avg_len = df[col].dropna().astype(str).str.len().mean()
            unique_frac = df[col].nunique(dropna=True) / len(df)
            if avg_len < maxStrLen and unique_frac < maxUniqueFrac:
                usableCols.append(col)
        else:
            usableCols.append(col)

    nVars = len(usableCols)
    if nVars == 0:
        print("No suitable columns to plot.")
        return

    nRows = math.ceil(nVars / nCols)
    figWidth = figWidthPerPlot * nCols
    figHeight = figHeightPerRow * nRows

    palette = sns.color_palette("Pastel1", n_colors=nVars)

    fig, axes = plt.subplots(nRows, nCols, figsize=(figWidth, figHeight), squeeze=False)
    axes = axes.flatten()

    for i, col in enumerate(usableCols):
        ax = axes[i]
        if pd.api.types.is_numeric_dtype(df[col]):
            sns.histplot(data=df, x=col, ax=ax, color=palette[i % len(palette)], bins=30, kde=False)
        else:
            sns.countplot(data=df, x=col, ax=ax, color=palette[i % len(palette)])
            ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')

        ax.set_title(col, fontsize=12)
        ax.set_xlabel("")
        ax.set_ylabel("")
        ax.grid(color='#b2d6c7', linewidth=1, axis='y', alpha=.3)
        ax.set_facecolor((1, 1, 1, 0.9))
        ax.patch.set_edgecolor('black')

    for j in range(nVars, nRows * nCols):
        fig.delaxes(axes[j])

    if title:
        plt.suptitle(title, fontsize=18, color='grey', fontweight='bold', y=1.02)

    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()

plotFrequencyGridSmart(engineeredDf, title="Frequencies and Distributions of Variables")

# %%
def plotBoxplotGrid(df, cols=None, nCols=8, figHeightPerRow=4, figWidthPerPlot=2.5, title=None):
    if cols is None:
        cols = [col for col in df.select_dtypes(include=[np.number]).columns]
    nVars = len(cols)
    nRows = math.ceil(nVars / nCols)
    figWidth = figWidthPerPlot * nCols
    figHeight = figHeightPerRow * nRows

    palette = sns.color_palette("Pastel1", n_colors=nVars)

    fig, axes = plt.subplots(nRows, nCols, figsize=(figWidth, figHeight), squeeze=False)
    axes = axes.flatten()
    for i, col in enumerate(cols):
        sns.boxplot(y=df[col], ax=axes[i], color=palette[i % len(palette)], width=0.6, fliersize=2)
        axes[i].set_title(col, fontsize=12)
        axes[i].set_ylabel("")
        #axes[i].set_yticklabels([])
        axes[i].set_xticks([])
        axes[i].grid(color='#b2d6c7', linewidth=1, axis='y', alpha=.3)
        axes[i].set_facecolor((1, 1, 1, 0.9))
        axes[i].patch.set_edgecolor('black')
    
    for j in range(nVars, nRows * nCols):
        fig.delaxes(axes[j])
    if title:
        plt.suptitle(title, fontsize=18, color='grey', fontweight='bold', y=1.02)
    plt.tight_layout(rect=[0, 0, 1, 0.98])
    plt.show()

numericCols = [col for col in engineeredDf.select_dtypes(include=[np.number]).columns]
plotBoxplotGrid(engineeredDf, cols=numericCols, nCols=8, figHeightPerRow=4, figWidthPerPlot=2.5, title="Outliers Detection in Variables")

# %%
engineeredDf.columns
# Out:
# Index(['Manufacturernumber', 'Articlenumber', 'EAN', 'Technical details',
#        'Picture normal reduced', 'Depth m', 'Width m', 'Length m', 'Weight kg',
#        'Delivery time days', 'Type of product', 'Price quantity',
#        'ETIM Features', 'ETIM', 'Short description', 'Short description 2',
#        'Long description', 'Language', 'Manufacturername', 'total_good',
#        'total_bad', 'Manufacturer_product_count', 'Product_length_category',
#        'Volume_m3', 'Description_length'],
#       dtype='object')

# %%
engineeredDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Manufacturernumber          308 non-null    object
#  1   Articlenumber               308 non-null    object
#  2   EAN                         282 non-null    float64
#  3   Technical details           304 non-null    object
#  4   Picture normal reduced      304 non-null    object
#  5   Depth m                     264 non-null    float64
#  6   Width m                     264 non-null    float64
#  7   Length m                    264 non-null    float64
#  8   Weight kg                   304 non-null    float64
#  9   Delivery time days          4 non-null      float64
#  10  Type of product             241 non-null    object
#  11  Price quantity              308 non-null    int64
#  12  ETIM Features               44 non-null     object
#  13  ETIM                        44 non-null     object
#  14  Short description           304 non-null    object
#  15  Short description 2         137 non-null    object
#  16  Long description            280 non-null    object
#  17  Language                    308 non-null    object
#  18  Manufacturername            308 non-null    object
#  19  total_good                  308 non-null    int64
#  20  total_bad                   308 non-null    int64
#  21  Manufacturer_product_count  308 non-null    int64
#  22  Product_length_category     261 non-null    category
#  23  Volume_m3                   308 non-null    float64
#  24  Description_length          308 non-null    int64
# dtypes: category(1), float64(7), int64(5), object(12)
# memory usage: 58.3+ KB

# %%
engineeredDf.isnull().sum()
# Out:
# Manufacturernumber              0
# Articlenumber                   0
# EAN                            26
# Technical details               4
# Picture normal reduced          4
# Depth m                        44
# Width m                        44
# Length m                       44
# Weight kg                       4
# Delivery time days            304
# Type of product                67
# Price quantity                  0
# ETIM Features                 264
# ETIM                          264
# Short description               4
# Short description 2           171
# Long description               28
# Language                        0
# Manufacturername                0
# total_good                      0
# total_bad                       0
# Manufacturer_product_count      0
# Product_length_category        47
# Volume_m3                       0
# Description_length              0
# dtype: int64

# %%
engineeredDf.to_csv("../data/product_catalog_cleaned.csv", index=False)
